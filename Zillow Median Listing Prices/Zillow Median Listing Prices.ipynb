# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read full Zillow csv file
df = pd.read_csv('Zillow Median Listing Price.csv')
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  3/31/2018  \
# 0      102001         0    United States    country       NaN   263267.0
# 1      394913         1     New York, NY        msa        NY   503000.0
# 2      753899         2  Los Angeles, CA        msa        CA   721333.0
# 3      394463         3      Chicago, IL        msa        IL   284600.0
# 4      394514         4       Dallas, TX        msa        TX   322997.0
# ..        ...       ...              ...        ...       ...        ...
# 920    753929       935       Zapata, TX        msa        TX        NaN
# 921    394743       936    Ketchikan, AK        msa        AK   284500.0
# 922    753874       937        Craig, CO        msa        CO   192833.0
# 923    395188       938       Vernon, TX        msa        TX        NaN
# 924    394767       939       Lamesa, TX        msa        TX    96800.0
#
#      4/30/2018  5/31/2018  6/30/2018  7/31/2018  ...  6/30/2022  7/31/2022  \
# ...

# %% [markdown]
# # Clean Data for Florida

# %%
#create df for just florida
FL_df = df.loc[df['StateName'] == "FL"]

FL_df = FL_df.drop(columns=['RegionID', 'SizeRank', 'RegionType'])

FL_df
# Out:
#                 RegionName StateName  3/31/2018  4/30/2018  5/31/2018  \
# 8                Miami, FL        FL   366600.0   368267.0   371067.0
# 18               Tampa, FL        FL   243950.0   247250.0   250616.0
# 22             Orlando, FL        FL   275450.0   280633.0   285600.0
# 39        Jacksonville, FL        FL   274867.0   278633.0   281933.0
# 72          North Port, FL        FL   336267.0   336258.0   336291.0
# 77          Cape Coral, FL        FL   282633.0   282633.0   281300.0
# 81            Lakeland, FL        FL   207967.0   211300.0   213333.0
# 89             Deltona, FL        FL   249600.0   251517.0   254850.0
# 96            Palm Bay, FL        FL   253916.0   257216.0   259632.0
# 110          Pensacola, FL        FL   237085.0   240593.0   244533.0
# 114     Port St. Lucie, FL        FL   261233.0   262867.0   263400.0
# 144        Tallahassee, FL        FL   204450.0   208359.0   210819.0
# ...

# %%
#create averages for florida
averages = FL_df.mean()

average_dict = {"Average": averages}

FL_averages = pd.DataFrame(average_dict)
FL_averages = FL_averages.reset_index()

FL_averages
# Out:
# C:\Users\jfroe\AppData\Local\Temp\ipykernel_25976\3335782161.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   averages = FL_df.mean()
#          index        Average
# 0    3/31/2018  268811.965517
# 1    4/30/2018  270345.137931
# 2    5/31/2018  271607.103448
# 3    6/30/2018  273491.586207
# 4    7/31/2018  274336.827586
# ..         ...            ...
# 56  11/30/2022  395599.310345
# 57  12/31/2022  394528.793103
# 58   1/31/2023  395470.034483
# 59   2/28/2023  398191.965517
# 60   3/31/2023  402547.413793
#
# [61 rows x 2 columns]

# %%
#change index to just include the year and then group by year for florida
def extract_year(date_string):
    return date_string[-4:]

FL_averages['index'] = FL_averages['index'].apply(extract_year)

FL_averages_year_group = FL_averages.groupby('index').mean()

FL_averages_year_group
# Out:
#              Average
# index
# 2018   273135.158621
# 2019   283426.491379
# 2020   293186.183908
# 2021   309145.953240
# 2022   383121.688116
# 2023   398736.471264

# %% [markdown]
# # Clean Data for US

# %%
#create df for the United States

USA_df = df.loc[df['RegionName'] == "United States"]

USA_df = USA_df.drop(columns=['RegionID', 'SizeRank', 'RegionType', 'StateName'])

USA_df
# Out:
#       RegionName  3/31/2018  4/30/2018  5/31/2018  6/30/2018  7/31/2018  \
# 0  United States   263267.0   271267.0   276633.0   280000.0   280300.0
#
#    8/31/2018  9/30/2018  10/31/2018  11/30/2018  ...  6/30/2022  7/31/2022  \
# 0   279633.0   279600.0    279300.0    278933.0  ...   387967.0   393300.0
#
#    8/31/2022  9/30/2022  10/31/2022  11/30/2022  12/31/2022  1/31/2023  \
# 0   393300.0   391300.0    386633.0    381667.0    375733.0   371900.0
#
#    2/28/2023  3/31/2023
# 0   371900.0     374833
#
# [1 rows x 62 columns]

# %%
#create averages for the US

averages_US = USA_df.mean()

average_dict_US = {"Average": averages_US}

US_averages = pd.DataFrame(average_dict_US)
US_averages = US_averages.reset_index()

US_averages
# Out:
# C:\Users\jfroe\AppData\Local\Temp\ipykernel_25976\93846891.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   averages_US = USA_df.mean()
#          index   Average
# 0    3/31/2018  263267.0
# 1    4/30/2018  271267.0
# 2    5/31/2018  276633.0
# 3    6/30/2018  280000.0
# 4    7/31/2018  280300.0
# ..         ...       ...
# 56  11/30/2022  381667.0
# 57  12/31/2022  375733.0
# 58   1/31/2023  371900.0
# 59   2/28/2023  371900.0
# 60   3/31/2023  374833.0
#
# [61 rows x 2 columns]

# %%
#change index to just include the year and then group by year for US


US_averages['index'] = US_averages['index'].apply(extract_year)

US_averages_year_group = US_averages.groupby('index').mean()

US_averages_year_group
# Out:
#              Average
# index
# 2018   276623.300000
# 2019   289633.333333
# 2020   303013.833333
# 2021   329973.916667
# 2022   371780.583333
# 2023   372877.666667

# %% [markdown]
# # Clean Data for Georgia

# %%
#create df for the Georgia

GA_df = df.loc[df['StateName'] == "GA"]

GA_df = GA_df.drop(columns=['RegionID', 'SizeRank', 'RegionType'])

GA_df
# Out:
#             RegionName StateName  3/31/2018  4/30/2018  5/31/2018  6/30/2018  \
# 9          Atlanta, GA        GA   280600.0   289900.0   296600.0   299633.0
# 95         Augusta, GA        GA   206783.0   210450.0   214933.0   216599.0
# 137       Savannah, GA        GA   262050.0   266017.0   267650.0   269100.0
# 157       Columbus, GA        GA   157400.0   162400.0   165050.0   167050.0
# 198          Macon, GA        GA   143300.0   144933.0   146467.0   149800.0
# 214         Athens, GA        GA   262400.0   265400.0   269467.0   275767.0
# 223    Gainesville, GA        GA   326450.0   331383.0   336567.0   344900.0
# 231  Warner Robins, GA        GA   159850.0   165150.0   170617.0   171583.0
# 291         Albany, GA        GA   131900.0   131916.0   133217.0   133267.0
# 296       Valdosta, GA        GA   157267.0   159767.0   164200.0   166722.0
# 301         Dalton, GA        GA   167933.0   167467.0   167467.0   169433.0
# ...

# %%
#create averages for the Georgia

averages_GA = GA_df.mean()

average_dict_GA = {"Average": averages_GA}

GA_averages = pd.DataFrame(average_dict_GA)
GA_averages = GA_averages.reset_index()

GA_averages
# Out:
# C:\Users\jfroe\AppData\Local\Temp\ipykernel_25976\527116950.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   averages_GA = GA_df.mean()
#          index        Average
# 0    3/31/2018  180641.027027
# 1    4/30/2018  183091.783784
# 2    5/31/2018  186936.162162
# 3    6/30/2018  189519.378378
# 4    7/31/2018  190505.081081
# ..         ...            ...
# 56  11/30/2022  254828.540541
# 57  12/31/2022  253719.648649
# 58   1/31/2023  252142.864865
# 59   2/28/2023  253186.324324
# 60   3/31/2023  257317.567568
#
# [61 rows x 2 columns]

# %%
#change index to just include the year and then group by year for Georgia

def extract_year(date_string):
    return date_string[-4:]

GA_averages['index'] = GA_averages['index'].apply(extract_year)

GA_averages_year_group = GA_averages.groupby('index').mean()

GA_averages_year_group
# Out:
#              Average
# index
# 2018   187446.218919
# 2019   195737.655405
# 2020   206380.743493
# 2021   221614.045045
# 2022   244962.259009
# 2023   254215.585586

# %% [markdown]
# # Clean Data for Ohio

# %%
#create df for the Ohio

OH_df = df.loc[df['StateName'] == "OH"]

OH_df = OH_df.drop(columns=['RegionID', 'SizeRank', 'RegionType'])

OH_df
# Out:
#                      RegionName StateName  3/31/2018  4/30/2018  5/31/2018  \
# 28               Cincinnati, OH        OH   199233.0   211233.0   221300.0
# 32                 Columbus, OH        OH   233267.0   241567.0   249600.0
# 34                Cleveland, OH        OH   159967.0   165800.0   171000.0
# 73                   Dayton, OH        OH   130300.0   135267.0   140267.0
# 82                    Akron, OH        OH   144600.0   151267.0   159250.0
# 92                   Toledo, OH        OH   140600.0   147267.0   154600.0
# 105              Youngstown, OH        OH   111600.0   114283.0   117583.0
# 136                  Canton, OH        OH   137900.0   142767.0   146133.0
# 150              Huntington, WV        OH   144317.0   144667.0   146333.0
# 305                Wheeling, WV        OH   128567.0   131750.0   135050.0
# 312             Springfield, OH        OH   104833.0   106567.0   110567.0
# ...

# %%
#create averages for the Ohio

averages_OH = OH_df.mean()

average_dict_OH = {"Average": averages_OH}

OH_averages = pd.DataFrame(average_dict_OH)
OH_averages = OH_averages.reset_index()

OH_averages
# Out:
# C:\Users\jfroe\AppData\Local\Temp\ipykernel_25976\914580635.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   averages_OH = OH_df.mean()
#          index        Average
# 0    3/31/2018  129856.173913
# 1    4/30/2018  133490.847826
# 2    5/31/2018  138240.478261
# 3    6/30/2018  141248.673913
# 4    7/31/2018  142247.826087
# ..         ...            ...
# 56  11/30/2022  184062.260870
# 57  12/31/2022  182881.760870
# 58   1/31/2023  182509.369565
# 59   2/28/2023  182062.891304
# 60   3/31/2023  185732.869565
#
# [61 rows x 2 columns]

# %%
#change index to just include the year and then group by year for Ohio

def extract_year(date_string):
    return date_string[-4:]

OH_averages['index'] = OH_averages['index'].apply(extract_year)

OH_averages_year_group = OH_averages.groupby('index').mean()

OH_averages_year_group
# Out:
#              Average
# index
# 2018   138633.017391
# 2019   145051.094203
# 2020   151633.750000
# 2021   161839.865942
# 2022   176784.900362
# 2023   183435.043478

# %% [markdown]
# # Clean Data for California

# %%
#create df for the California

CA_df = df.loc[df['StateName'] == "CA"]

CA_df = CA_df.drop(columns=['RegionID', 'SizeRank', 'RegionType'])

CA_df
# Out:
#               RegionName StateName  3/31/2018  4/30/2018  5/31/2018  \
# 2        Los Angeles, CA        CA   721333.0   735000.0   743333.0
# 12     San Francisco, CA        CA   864333.0   907667.0   929000.0
# 13         Riverside, CA        CA   377967.0   382667.0   386300.0
# 17         San Diego, CA        CA   653147.0   664730.0   671067.0
# 26        Sacramento, CA        CA   434667.0   443000.0   446667.0
# 35          San Jose, CA        CA  1122633.0  1171967.0  1190633.0
# 56            Fresno, CA        CA   294317.0   297317.0   302317.0
# 62       Bakersfield, CA        CA   255567.0   260600.0   263967.0
# 70            Oxnard, CA        CA   692786.0   696120.0   699467.0
# 76          Stockton, CA        CA   372667.0   374667.0   376300.0
# 102          Modesto, CA        CA   337667.0   342633.0   347633.0
# 111       Santa Rosa, CA        CA   736667.0   728000.0   723208.0
# 118          Visalia, CA        CA   244633.0   251300.0   259165.0
# ...

# %%
#create averages for the California

averages_CA = CA_df.mean()

average_dict_CA = {"Average": averages_CA}

CA_averages = pd.DataFrame(average_dict_CA)
CA_averages = CA_averages.reset_index()

CA_averages
# Out:
# C:\Users\jfroe\AppData\Local\Temp\ipykernel_25976\982391137.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   averages_CA = CA_df.mean()
#          index        Average
# 0    3/31/2018  489275.500000
# 1    4/30/2018  496057.676471
# 2    5/31/2018  500220.294118
# 3    6/30/2018  505040.588235
# 4    7/31/2018  504491.000000
# ..         ...            ...
# 56  11/30/2022  630651.352941
# 57  12/31/2022  625627.647059
# 58   1/31/2023  621465.382353
# 59   2/28/2023  624800.970588
# 60   3/31/2023  632725.088235
#
# [61 rows x 2 columns]

# %%
#change index to just include the year and then group by year for California

def extract_year(date_string):
    return date_string[-4:]

CA_averages['index'] = CA_averages['index'].apply(extract_year)

CA_averages_year_group = CA_averages.groupby('index').mean()

CA_averages_year_group
# Out:
#              Average
# index
# 2018   496081.597059
# 2019   506812.830882
# 2020   541691.078431
# 2021   590211.959150
# 2022   636704.904412
# 2023   626330.480392

# %% [markdown]
# # Clean Data for Texas

# %%
#create df for the Texas

TX_df = df.loc[df['StateName'] == "TX"]

TX_df = TX_df.drop(columns=['RegionID', 'SizeRank', 'RegionType'])

TX_df
# Out:
#           RegionName StateName  3/31/2018  4/30/2018  5/31/2018  6/30/2018  \
# 4         Dallas, TX        TX   322997.0   328497.0   331797.0   332800.0
# 5        Houston, TX        TX   294467.0   297933.0   299633.0   299933.0
# 24   San Antonio, TX        TX   256667.0   260667.0   265633.0   268933.0
# 29        Austin, TX        TX   362567.0   367600.0   370717.0   372084.0
# 66       McAllen, TX        TX   183817.0   185167.0   185667.0   187667.0
# ..               ...       ...        ...        ...        ...        ...
# 913       Snyder, TX        TX   134283.0   133633.0   135633.0   138417.0
# 919   Sweetwater, TX        TX   124471.0   117938.0   111604.0   109633.0
# 920       Zapata, TX        TX        NaN        NaN        NaN        NaN
# 923       Vernon, TX        TX        NaN        NaN        NaN        NaN
# 924       Lamesa, TX        TX    96800.0   103467.0   108450.0   114650.0
#
# ...

# %%
#create averages for the Texas

averages_TX = TX_df.mean()

average_dict_TX = {"Average": averages_TX}

TX_averages = pd.DataFrame(average_dict_TX)
TX_averages = TX_averages.reset_index()

TX_averages
# Out:
# C:\Users\jfroe\AppData\Local\Temp\ipykernel_25976\357479016.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   averages_TX = TX_df.mean()
#          index        Average
# 0    3/31/2018  206794.206349
# 1    4/30/2018  210218.380952
# 2    5/31/2018  214000.873016
# 3    6/30/2018  217468.873016
# 4    7/31/2018  217732.920635
# ..         ...            ...
# 56  11/30/2022  277938.455882
# 57  12/31/2022  278986.666667
# 58   1/31/2023  279224.600000
# 59   2/28/2023  277120.014286
# 60   3/31/2023  277598.285714
#
# [61 rows x 2 columns]

# %%
#change index to just include the year and then group by year for Texas

def extract_year(date_string):
    return date_string[-4:]

TX_averages['index'] = TX_averages['index'].apply(extract_year)

TX_averages_year_group = TX_averages.groupby('index').mean()

TX_averages_year_group
# Out:
#              Average
# index
# 2018   214098.490476
# 2019   219152.404762
# 2020   228666.062199
# 2021   243089.733304
# 2022   274661.847222
# 2023   277980.966667

# %% [markdown]
# # Charts

# %%
plt.figure(figsize=(10,6))
plt.plot(FL_averages_year_group, label="FL")
plt.title('Florida Median Listing Prices (2018-2023)')
plt.xlabel('Year')
plt.ylabel('Median House Price ($)')
plt.legend(loc='best')
plt.savefig("Florida Median Listing Prices (2018-2023).png")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(FL_averages_year_group, label="FL")
plt.plot(US_averages_year_group, label="US")
plt.title('Florida vs. US Median Listing Prices (2018-2023)')
plt.xlabel('Year')
plt.ylabel('Median House Price ($)')
plt.legend(loc='best')
plt.savefig('Florida vs. US Median Listing Prices (2018-2023).png')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(FL_averages_year_group, label="FL")
plt.plot(GA_averages_year_group, label="GA")
plt.plot(OH_averages_year_group, label="OH")
plt.plot(CA_averages_year_group, label="CA")
plt.plot(TX_averages_year_group, label="TX")
plt.title('State Median Listing Prices (2018-2023)')
plt.xlabel('Year')
plt.ylabel('Median House Price ($)')
plt.legend(loc='best')
plt.savefig("State Median Listing Prices (2018-2023).png")
plt.show()
