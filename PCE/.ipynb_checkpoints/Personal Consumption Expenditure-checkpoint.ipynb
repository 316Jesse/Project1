# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

all_pce_data = pd.read_csv('SAPCE1__ALL_AREAS_1997_2021.csv')
all_pce_data.columns
# Out:
# Index(['GeoFIPS', 'GeoName', 'Region', 'TableName', 'LineCode',
#        'IndustryClassification', 'Description', 'Unit', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', '1998 YOY %', '1999 YOY %',
#        '2000 YOY %', '2001 YOY %', '2002 YOY %', '2003 YOY %', '2004 YOY %',
#        '2005 YOY %', '2006 YOY %', '2007 YOY %', '2008 YOY %', '2009 YOY %',
#        '2010 YOY %', '2011 YOY %', '2012 YOY %', '2013 YOY %', '2014 YOY %',
#        '2015 YOY %', '2016 YOY %', '2017 YOY %', '2018 YOY %', '2019 YOY %',
#        '2020 YOY %', '2021 YOY %'],
#       dtype='object')

# %%
pd.options.display.max_columns = 25
PCE_data = all_pce_data[['GeoName','Description','1998 YOY %','1999 YOY %','2000 YOY %','2001 YOY %','2002 YOY %',
                            '2003 YOY %','2004 YOY %','2005 YOY %','2006 YOY %','2007 YOY %','2008 YOY %','2009 YOY %','2010 YOY %',
                            '2011 YOY %','2012 YOY %','2013 YOY %','2014 YOY %','2015 YOY %','2016 YOY %','2017 YOY %','2018 YOY %',
                            '2019 YOY %','2020 YOY %' ]]

PCE_data.set_index('Description', inplace=True)
florida_PCE_data = PCE_data.loc[PCE_data['GeoName']=='Florida']
#florida_PCE_data.sort_values('1998 YOY %', ascending=False, inplace=True)
florida_PCE_data
# Out:
#                                                     GeoName 1998 YOY %  \
# Description
# Personal consumption expenditures                   Florida      6.75%
#  Goods                                              Florida      6.46%
#   Durable goods                                     Florida      9.17%
#    Motor vehicles and parts                         Florida      9.57%
#    Furnishings and durable household equipment      Florida     10.46%
#    Recreational goods and vehicles                  Florida      8.48%
#    Other durable goods                              Florida      6.66%
#   Nondurable goods                                  Florida      4.71%
#    Food and beverages purchased for off-premise...  Florida      5.53%
#    Clothing and footwear                            Florida      3.68%
#    Gasoline and other energy goods                  Florida     -5.68%
#    Other nondurable goods                           Florida      7.28%
# ...
