# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# This method is used to 
files = ['2021_census_migration.csv', 
         '2019_census_migration.csv', 
         '2018_census_migration.csv', 
         '2017_census_migration.csv', 
         '2016_census_migration.csv', 
         '2015_census_migration.csv', 
         '2014_census_migration.csv', 
         '2013_census_migration.csv', 
         '2012_census_migration.csv', 
         '2011_census_migration.csv', 
         '2010_census_migration.csv']

# %%
df_list = []
for file in files:
    df = pd.read_csv(file, encoding='utf-8')
    df_list.append(df)

merged_df = pd.concat(df_list, axis=1)

#This is to output a saved merged file...file is already in the folder so no need to run the below code
#merged_df.to_csv('merged_census_data.csv', index=False)

# %%
# Name of the CSV file
file = Path('merged_census_data.csv')

# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file,encoding='UTF-8')
df
# Out:
#                                      Label (Grouping)  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62          Householder lived in owner-occupied ho...
# 63          Householder lived in renter-occupied h...
# 64                                  PERCENT ALLOCATED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate Florida!!Total!!Margin of Error  \
# 0                21,590,684                          ±8,058
# 1                       NaN                             NaN
# 2                   901,510                          ±8,772
# 3                 3,195,869                          ±4,131
# 4                 1,731,183                          ±7,357
# ..                      ...                             ...
# 61               21,178,225                          ±8,058
# 62               14,483,276                         ±75,641
# 63                6,694,949                         ±74,894
# 64                      NaN                             NaN
# 65                   11.90%                             (X)
#
#    Florida!!Moved; within same county!!Estimate  \
# 0                                         7.10%
# 1                                           NaN
# 2                                        10.30%
# 3                                         7.60%
# 4                                        10.50%
# ..                                          ...
# 61                                        6.90%
# 62                                        4.50%
# 63                                       12.20%
# 64                                          NaN
# 65                                          (X)
#
#    Florida!!Moved; within same county!!Margin of Error  \
# 0                                                ±0.2
# 1                                                 NaN
# 2                                                ±1.0
# 3                                                ±0.5
# 4                                                ±0.6
# ..                                                ...
# 61                                               ±0.2
# 62                                               ±0.2
# 63                                               ±0.4
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate  \
# 0                                               3.10%
# 1                                                 NaN
# 2                                               3.80%
# 3                                               2.60%
# 4                                               7.80%
# ..                                                ...
# 61                                              2.80%
# 62                                              2.00%
# 63                                              4.40%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.2
# 4                                                ±0.5
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate  \
# 0                                            3.10%
# 1                                              NaN
# 2                                            3.20%
# 3                                            2.60%
# 4                                            4.80%
# ..                                             ...
# 61                                           3.00%
# 62                                           2.40%
# 63                                           4.40%
# 64                                             NaN
# 65                                             (X)
#
#    Florida!!Moved; from different  state!!Margin of Error  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.5
# 3                                                ±0.3
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.3
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate  \
# 0                                  0.60%
# 1                                    NaN
# 2                                  0.90%
# 3                                  0.60%
# 4                                  0.90%
# ..                                   ...
# 61                                 0.60%
# 62                                 0.40%
# 63                                 1.10%
# 64                                   NaN
# 65                                   (X)
#
#    Florida!!Moved; from abroad!!Margin of Error  \
# 0                                          ±0.1
# 1                                           NaN
# 2                                          ±0.3
# 3                                          ±0.1
# 4                                          ±0.1
# ..                                          ...
# 61                                         ±0.1
# 62                                         ±0.1
# 63                                         ±0.1
# 64                                          NaN
# 65                                          (X)
#
#                                    Label (Grouping).1  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62          Householder lived in owner-occupied ho...
# 63          Householder lived in renter-occupied h...
# 64                                  PERCENT ALLOCATED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate.1 Florida!!Total!!Margin of Error.1  \
# 0                  21,269,409                            ±9,193
# 1                         NaN                               NaN
# 2                     922,820                           ±10,242
# 3                   3,100,807                            ±5,278
# 4                   1,761,280                            ±7,725
# ..                        ...                               ...
# 61                 20,839,700                            ±9,226
# 62                 13,854,415                           ±82,414
# 63                  6,985,285                           ±82,227
# 64                        NaN                               NaN
# 65                      9.50%                               (X)
#
#    Florida!!Moved; within same county!!Estimate.1  \
# 0                                           8.10%
# 1                                             NaN
# 2                                          11.90%
# 3                                           8.50%
# 4                                          11.60%
# ..                                            ...
# 61                                          8.00%
# 62                                          4.80%
# 63                                         14.30%
# 64                                            NaN
# 65                                            (X)
#
#    Florida!!Moved; within same county!!Margin of Error.1  \
# 0                                                ±0.2
# 1                                                 NaN
# 2                                                ±0.8
# 3                                                ±0.5
# 4                                                ±0.6
# ..                                                ...
# 61                                               ±0.2
# 62                                               ±0.2
# 63                                               ±0.5
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate.1  \
# 0                                               3.10%
# 1                                                 NaN
# 2                                               3.10%
# 3                                               2.50%
# 4                                               6.80%
# ..                                                ...
# 61                                              2.60%
# 62                                              1.80%
# 63                                              4.30%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error.1  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.3
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate.1  \
# 0                                              2.80%
# 1                                                NaN
# 2                                              3.20%
# 3                                              2.00%
# 4                                              4.60%
# ..                                               ...
# 61                                             2.70%
# 62                                             2.20%
# 63                                             3.90%
# 64                                               NaN
# 65                                               (X)
#
#    Florida!!Moved; from different  state!!Margin of Error.1  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.2
# 4                                                ±0.3
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.3
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate.1  \
# 0                                    1.00%
# 1                                      NaN
# 2                                    1.10%
# 3                                    1.00%
# 4                                    1.60%
# ..                                     ...
# 61                                   0.90%
# 62                                   0.60%
# 63                                   1.70%
# 64                                     NaN
# 65                                     (X)
#
#    Florida!!Moved; from abroad!!Margin of Error.1  \
# 0                                            ±0.1
# 1                                             NaN
# 2                                            ±0.3
# 3                                            ±0.1
# 4                                            ±0.2
# ..                                            ...
# 61                                           ±0.1
# 62                                           ±0.1
# 63                                           ±0.2
# 64                                            NaN
# 65                                            (X)
#
#                                    Label (Grouping).2  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62          Householder lived in owner-occupied ho...
# 63          Householder lived in renter-occupied h...
# 64                                  PERCENT ALLOCATED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate.2 Florida!!Total!!Margin of Error.2  \
# 0                  21,092,877                            ±8,313
# 1                         NaN                               NaN
# 2                     928,944                            ±8,001
# 3                   3,092,483                            ±5,060
# 4                   1,769,325                            ±8,687
# ..                        ...                               ...
# 61                 20,662,745                            ±8,361
# 62                 13,611,613                           ±82,589
# 63                  7,051,132                           ±82,642
# 64                        NaN                               NaN
# 65                      9.20%                               (X)
#
#    Florida!!Moved; within same county!!Estimate.2  \
# 0                                           8.30%
# 1                                             NaN
# 2                                          12.20%
# 3                                           8.90%
# 4                                          12.40%
# ..                                            ...
# 61                                          8.10%
# 62                                          4.80%
# 63                                         14.50%
# 64                                            NaN
# 65                                            (X)
#
#    Florida!!Moved; within same county!!Margin of Error.2  \
# 0                                                ±0.2
# 1                                                 NaN
# 2                                                ±0.9
# 3                                                ±0.5
# 4                                                ±0.6
# ..                                                ...
# 61                                               ±0.2
# 62                                               ±0.2
# 63                                               ±0.5
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate.2  \
# 0                                               3.20%
# 1                                                 NaN
# 2                                               3.40%
# 3                                               2.60%
# 4                                               7.10%
# ..                                                ...
# 61                                              2.80%
# 62                                              2.00%
# 63                                              4.20%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error.2  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.5
# 3                                                ±0.2
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate.2  \
# 0                                              2.80%
# 1                                                NaN
# 2                                              3.10%
# 3                                              2.30%
# 4                                              4.00%
# ..                                               ...
# 61                                             2.70%
# 62                                             2.10%
# 63                                             3.90%
# 64                                               NaN
# 65                                               (X)
#
#    Florida!!Moved; from different  state!!Margin of Error.2  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.3
# 4                                                ±0.3
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate.2  \
# 0                                    1.10%
# 1                                      NaN
# 2                                    1.00%
# 3                                    1.20%
# 4                                    1.50%
# ..                                     ...
# 61                                   1.00%
# 62                                   0.60%
# 63                                   1.90%
# 64                                     NaN
# 65                                     (X)
#
#    Florida!!Moved; from abroad!!Margin of Error.2  \
# 0                                            ±0.1
# 1                                             NaN
# 2                                            ±0.2
# 3                                            ±0.2
# 4                                            ±0.2
# ..                                            ...
# 61                                           ±0.1
# 62                                           ±0.1
# 63                                           ±0.2
# 64                                            NaN
# 65                                            (X)
#
#                                    Label (Grouping).3  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62          Householder lived in owner-occupied ho...
# 63          Householder lived in renter-occupied h...
# 64                                  PERCENT ALLOCATED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate.3 Florida!!Total!!Margin of Error.3  \
# 0                  20,772,371                            ±8,045
# 1                         NaN                               NaN
# 2                     917,293                            ±9,292
# 3                   3,071,458                            ±4,585
# 4                   1,763,443                            ±7,379
# ..                        ...                               ...
# 61                 20,344,787                            ±8,073
# 62                 13,200,134                           ±74,943
# 63                  7,144,653                           ±75,932
# 64                        NaN                               NaN
# 65                      8.60%                               (X)
#
#    Florida!!Moved; within same county!!Estimate.3  \
# 0                                           8.40%
# 1                                             NaN
# 2                                          12.00%
# 3                                           9.20%
# 4                                          12.40%
# ..                                            ...
# 61                                          8.20%
# 62                                          5.00%
# 63                                         14.10%
# 64                                            NaN
# 65                                            (X)
#
#    Florida!!Moved; within same county!!Margin of Error.3  \
# 0                                                ±0.2
# 1                                                 NaN
# 2                                                ±0.8
# 3                                                ±0.5
# 4                                                ±0.6
# ..                                                ...
# 61                                               ±0.2
# 62                                               ±0.2
# 63                                               ±0.5
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate.3  \
# 0                                               3.20%
# 1                                                 NaN
# 2                                               3.60%
# 3                                               2.40%
# 4                                               6.90%
# ..                                                ...
# 61                                              2.70%
# 62                                              1.90%
# 63                                              4.30%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error.3  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.2
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate.3  \
# 0                                              2.70%
# 1                                                NaN
# 2                                              2.90%
# 3                                              1.90%
# 4                                              4.30%
# ..                                               ...
# 61                                             2.60%
# 62                                             2.00%
# 63                                             3.80%
# 64                                               NaN
# 65                                               (X)
#
#    Florida!!Moved; from different  state!!Margin of Error.3  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.5
# 3                                                ±0.2
# 4                                                ±0.3
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate.3  \
# 0                                    1.20%
# 1                                      NaN
# 2                                    1.40%
# 3                                    1.40%
# 4                                    1.50%
# ..                                     ...
# 61                                   1.20%
# 62                                   0.70%
# 63                                   2.20%
# 64                                     NaN
# 65                                     (X)
#
#    Florida!!Moved; from abroad!!Margin of Error.3  \
# 0                                            ±0.1
# 1                                             NaN
# 2                                            ±0.3
# 3                                            ±0.2
# 4                                            ±0.2
# ..                                            ...
# 61                                           ±0.1
# 62                                           ±0.1
# 63                                           ±0.2
# 64                                            NaN
# 65                                            (X)
#
#                                    Label (Grouping).4  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62          Householder lived in owner-occupied ho...
# 63          Householder lived in renter-occupied h...
# 64                                  PERCENT ALLOCATED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate.4 Florida!!Total!!Margin of Error.4  \
# 0                  20,401,575                            ±7,828
# 1                         NaN                               NaN
# 2                     906,603                            ±8,126
# 3                   3,027,673                            ±4,366
# 4                   1,763,628                            ±7,377
# ..                        ...                               ...
# 61                 19,968,183                            ±7,842
# 62                 12,721,641                           ±64,088
# 63                  7,246,542                           ±64,307
# 64                        NaN                               NaN
# 65                      7.90%                               (X)
#
#    Florida!!Moved; within same county!!Estimate.4  \
# 0                                           8.70%
# 1                                             NaN
# 2                                          13.50%
# 3                                           9.30%
# 4                                          13.50%
# ..                                            ...
# 61                                          8.50%
# 62                                          4.90%
# 63                                         14.80%
# 64                                            NaN
# 65                                            (X)
#
#    Florida!!Moved; within same county!!Margin of Error.4  \
# 0                                                ±0.2
# 1                                                 NaN
# 2                                                ±0.9
# 3                                                ±0.4
# 4                                                ±0.5
# ..                                                ...
# 61                                               ±0.2
# 62                                               ±0.2
# 63                                               ±0.4
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate.4  \
# 0                                               3.00%
# 1                                                 NaN
# 2                                               3.10%
# 3                                               2.30%
# 4                                               7.10%
# ..                                                ...
# 61                                              2.60%
# 62                                              1.80%
# 63                                              4.00%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error.4  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.2
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate.4  \
# 0                                              3.00%
# 1                                                NaN
# 2                                              3.50%
# 3                                              2.30%
# 4                                              4.00%
# ..                                               ...
# 61                                             2.90%
# 62                                             2.20%
# 63                                             4.10%
# 64                                               NaN
# 65                                               (X)
#
#    Florida!!Moved; from different  state!!Margin of Error.4  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.2
# 4                                                ±0.3
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate.4  \
# 0                                    1.10%
# 1                                      NaN
# 2                                    1.10%
# 3                                    1.10%
# 4                                    1.40%
# ..                                     ...
# 61                                   1.10%
# 62                                   0.60%
# 63                                   2.00%
# 64                                     NaN
# 65                                     (X)
#
#    Florida!!Moved; from abroad!!Margin of Error.4  \
# 0                                            ±0.1
# 1                                             NaN
# 2                                            ±0.3
# 3                                            ±0.1
# 4                                            ±0.2
# ..                                            ...
# 61                                           ±0.1
# 62                                           ±0.1
# 63                                           ±0.2
# 64                                            NaN
# 65                                            (X)
#
#                                    Label (Grouping).5  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62          Householder lived in owner-occupied ho...
# 63          Householder lived in renter-occupied h...
# 64                                    PERCENT IMPUTED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate.5 Florida!!Total!!Margin of Error.5  \
# 0                  20,068,392                            ±6,492
# 1                         NaN                               NaN
# 2                     895,393                            ±7,793
# 3                   3,004,716                            ±3,565
# 4                   1,774,002                            ±7,744
# ..                        ...                               ...
# 61                 19,637,960                            ±6,485
# 62                 12,434,521                           ±65,971
# 63                  7,203,439                           ±65,106
# 64                        NaN                               NaN
# 65                      7.90%                               (X)
#
#    Florida!!Moved; within same county!!Estimate.5  \
# 0                                           9.00%
# 1                                             NaN
# 2                                          13.60%
# 3                                          10.20%
# 4                                          13.50%
# ..                                            ...
# 61                                          8.80%
# 62                                          4.80%
# 63                                         15.80%
# 64                                            NaN
# 65                                            (X)
#
#    Florida!!Moved; within same county!!Margin of Error.5  \
# 0                                                ±0.2
# 1                                                 NaN
# 2                                                ±0.8
# 3                                                ±0.5
# 4                                                ±0.6
# ..                                                ...
# 61                                               ±0.2
# 62                                               ±0.2
# 63                                               ±0.5
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate.5  \
# 0                                               3.10%
# 1                                                 NaN
# 2                                               3.50%
# 3                                               2.40%
# 4                                               7.10%
# ..                                                ...
# 61                                              2.70%
# 62                                              1.70%
# 63                                              4.50%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error.5  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.2
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate.5  \
# 0                                              2.90%
# 1                                                NaN
# 2                                              3.40%
# 3                                              2.10%
# 4                                              4.30%
# ..                                               ...
# 61                                             2.80%
# 62                                             2.10%
# 63                                             4.10%
# 64                                               NaN
# 65                                               (X)
#
#    Florida!!Moved; from different  state!!Margin of Error.5  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.2
# 4                                                ±0.3
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate.5  \
# 0                                    1.10%
# 1                                      NaN
# 2                                    1.10%
# 3                                    1.00%
# 4                                    1.50%
# ..                                     ...
# 61                                   1.00%
# 62                                   0.70%
# 63                                   1.70%
# 64                                     NaN
# 65                                     (X)
#
#    Florida!!Moved; from abroad!!Margin of Error.5  \
# 0                                            ±0.1
# 1                                             NaN
# 2                                            ±0.3
# 3                                            ±0.1
# 4                                            ±0.2
# ..                                            ...
# 61                                           ±0.1
# 62                                           ±0.1
# 63                                           ±0.2
# 64                                            NaN
# 65                                            (X)
#
#                                    Label (Grouping).6  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62          Householder lived in owner-occupied ho...
# 63          Householder lived in renter-occupied h...
# 64                                    PERCENT IMPUTED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate.6 Florida!!Total!!Margin of Error.6  \
# 0                  19,683,763                            ±7,910
# 1                         NaN                               NaN
# 2                     868,038                            ±7,748
# 3                   2,976,451                            ±3,914
# 4                   1,798,078                            ±6,225
# ..                        ...                               ...
# 61                 19,252,300                            ±7,910
# 62                 12,234,061                           ±66,520
# 63                  7,018,239                           ±65,795
# 64                        NaN                               NaN
# 65                      7.40%                               (X)
#
#    Florida!!Moved; within same county!!Estimate.6  \
# 0                                           9.30%
# 1                                             NaN
# 2                                          13.60%
# 3                                          10.10%
# 4                                          14.40%
# ..                                            ...
# 61                                          9.10%
# 62                                          4.30%
# 63                                         17.40%
# 64                                            NaN
# 65                                            (X)
#
#    Florida!!Moved; within same county!!Margin of Error.6  \
# 0                                                ±0.2
# 1                                                 NaN
# 2                                                ±0.9
# 3                                                ±0.4
# 4                                                ±0.6
# ..                                                ...
# 61                                               ±0.2
# 62                                               ±0.1
# 63                                               ±0.4
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate.6  \
# 0                                               3.10%
# 1                                                 NaN
# 2                                               3.30%
# 3                                               2.50%
# 4                                               7.20%
# ..                                                ...
# 61                                              2.70%
# 62                                              1.50%
# 63                                              4.70%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error.6  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.3
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.2
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate.6  \
# 0                                              2.80%
# 1                                                NaN
# 2                                              3.20%
# 3                                              2.20%
# 4                                              4.10%
# ..                                               ...
# 61                                             2.70%
# 62                                             1.80%
# ...
# 62                                               ±0.1
# 63                                               ±0.3
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate.8  \
# 0                                    0.90%
# 1                                      NaN
# 2                                    1.00%
# 3                                    0.90%
# 4                                    1.10%
# ..                                     ...
# 61                                   0.90%
# 62                                   0.50%
# 63                                   1.50%
# 64                                     NaN
# 65                                     (X)
#
#    Florida!!Moved; from abroad!!Margin of Error.8  \
# 0                                            ±0.1
# 1                                             NaN
# 2                                            ±0.2
# 3                                            ±0.1
# 4                                            ±0.2
# ..                                            ...
# 61                                           ±0.1
# 62                                           ±0.1
# 63                                           ±0.2
# 64                                            NaN
# 65                                            (X)
#
#                                    Label (Grouping).9  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62      Householder lived in owner-occupied housin...
# 63      Householder lived in renter-occupied housi...
# 64                                    PERCENT IMPUTED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate.9 Florida!!Total!!Margin of Error.9  \
# 0                  18,863,948                            ±8,536
# 1                         NaN                               NaN
# 2                     880,730                            ±9,199
# 3                   2,920,626                            ±5,253
# 4                   1,795,011                            ±8,185
# ..                        ...                               ...
# 61                 18,442,356                            ±8,543
# 62                 12,291,643                           ±78,159
# 63                  6,150,713                           ±78,102
# 64                        NaN                               NaN
# 65                      4.90%                               (X)
#
#    Florida!!Moved; within same county!!Estimate.9  \
# 0                                          10.00%
# 1                                             NaN
# 2                                          15.60%
# 3                                          11.80%
# 4                                          16.50%
# ..                                            ...
# 61                                          9.80%
# 62                                          3.70%
# 63                                         22.10%
# 64                                            NaN
# 65                                            (X)
#
#    Florida!!Moved; within same county!!Margin of Error.9  \
# 0                                                ±0.3
# 1                                                 NaN
# 2                                                ±0.9
# 3                                                ±0.6
# 4                                                ±0.7
# ..                                                ...
# 61                                               ±0.3
# 62                                               ±0.2
# 63                                               ±0.7
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate.9  \
# 0                                               3.00%
# 1                                                 NaN
# 2                                               3.60%
# 3                                               2.10%
# 4                                               7.30%
# ..                                                ...
# 61                                              2.50%
# 62                                              1.20%
# 63                                              5.20%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error.9  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.5
# 3                                                ±0.2
# 4                                                ±0.5
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.3
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate.9  \
# 0                                              2.60%
# 1                                                NaN
# 2                                              3.10%
# 3                                              2.10%
# 4                                              4.10%
# ..                                               ...
# 61                                             2.50%
# 62                                             1.50%
# 63                                             4.50%
# 64                                               NaN
# 65                                               (X)
#
#    Florida!!Moved; from different  state!!Margin of Error.9  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.6
# 3                                                ±0.2
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.3
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate.9  \
# 0                                    0.90%
# 1                                      NaN
# 2                                    0.70%
# 3                                    0.80%
# 4                                    1.40%
# ..                                     ...
# 61                                   0.90%
# 62                                   0.60%
# 63                                   1.50%
# 64                                     NaN
# 65                                     (X)
#
#    Florida!!Moved; from abroad!!Margin of Error.9  \
# 0                                            ±0.1
# 1                                             NaN
# 2                                            ±0.2
# 3                                            ±0.1
# 4                                            ±0.3
# ..                                            ...
# 61                                           ±0.1
# 62                                           ±0.1
# 63                                           ±0.2
# 64                                            NaN
# 65                                            (X)
#
#                                   Label (Grouping).10  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62      Householder lived in owner-occupied housin...
# 63      Householder lived in renter-occupied housi...
# 64                                    PERCENT IMPUTED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate.10 Florida!!Total!!Margin of Error.10  \
# 0                   18,647,600                             ±7,733
# 1                          NaN                                NaN
# 2                      872,260                             ±7,986
# 3                    2,931,533                             ±5,076
# 4                    1,766,628                             ±7,478
# ..                         ...                                ...
# 61                  18,225,891                             ±7,733
# 62                  12,421,033                            ±60,338
# 63                   5,804,858                            ±59,928
# 64                         NaN                                NaN
# 65                       5.00%                                (X)
#
#    Florida!!Moved; within same county!!Estimate.10  \
# 0                                           10.30%
# 1                                              NaN
# 2                                           16.10%
# 3                                           11.40%
# 4                                           16.60%
# ..                                             ...
# 61                                          10.10%
# 62                                           3.80%
# 63                                          23.40%
# 64                                             NaN
# 65                                             (X)
#
#    Florida!!Moved; within same county!!Margin of Error.10  \
# 0                                                ±0.2
# 1                                                 NaN
# 2                                                ±0.9
# 3                                                ±0.5
# 4                                                ±0.6
# ..                                                ...
# 61                                               ±0.2
# 62                                               ±0.1
# 63                                               ±0.6
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Estimate.10  \
# 0                                               2.90%
# 1                                                 NaN
# 2                                               3.20%
# 3                                               2.30%
# 4                                               7.40%
# ..                                                ...
# 61                                              2.50%
# 62                                              1.30%
# 63                                              5.20%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different county, same state!!Margin of Error.10  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.2
# 4                                                ±0.5
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.3
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Estimate.10  \
# 0                                               2.60%
# 1                                                 NaN
# 2                                               2.90%
# 3                                               2.10%
# 4                                               4.00%
# ..                                                ...
# 61                                              2.50%
# 62                                              1.50%
# 63                                              4.50%
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from different  state!!Margin of Error.10  \
# 0                                                ±0.1
# 1                                                 NaN
# 2                                                ±0.3
# 3                                                ±0.2
# 4                                                ±0.4
# ..                                                ...
# 61                                               ±0.1
# 62                                               ±0.1
# 63                                               ±0.3
# 64                                                NaN
# 65                                                (X)
#
#    Florida!!Moved; from abroad!!Estimate.10  \
# 0                                     0.80%
# 1                                       NaN
# 2                                     0.50%
# 3                                     0.80%
# 4                                     1.30%
# ..                                      ...
# 61                                    0.80%
# 62                                    0.50%
# 63                                    1.40%
# 64                                      NaN
# 65                                      (X)
#
#    Florida!!Moved; from abroad!!Margin of Error.10
# 0                                             ±0.1
# 1                                              NaN
# 2                                             ±0.1
# 3                                             ±0.1
# 4                                             ±0.2
# ..                                             ...
# 61                                            ±0.1
# 62                                            ±0.1
# 63                                            ±0.2
# 64                                             NaN
# 65                                             (X)
#
# [66 rows x 121 columns]

# %%
# Out:
# Index(['Label (Grouping)', 'Florida!!Total!!Estimate',
#        'Florida!!Total!!Margin of Error',
#        'Florida!!Moved; within same county!!Estimate',
#        'Florida!!Moved; within same county!!Margin of Error',
#        'Florida!!Moved; from different county, same state!!Estimate',
#        'Florida!!Moved; from different county, same state!!Margin of Error',
#        'Florida!!Moved; from different  state!!Estimate',
#        'Florida!!Moved; from different  state!!Margin of Error',
#        'Florida!!Moved; from abroad!!Estimate',
#        ...
#        'Florida!!Total!!Estimate.10', 'Florida!!Total!!Margin of Error.10',
#        'Florida!!Moved; within same county!!Estimate.10',
#        'Florida!!Moved; within same county!!Margin of Error.10',
#        'Florida!!Moved; from different county, same state!!Estimate.10',
#        'Florida!!Moved; from different county, same state!!Margin of Error.10',
#        'Florida!!Moved; from different  state!!Estimate.10',
#        'Florida!!Moved; from different  state!!Margin of Error.10',
#        'Florida!!Moved; from abroad!!Estimate.10',
#        'Florida!!Moved; from abroad!!Margin of Error.10'],
#       dtype='object', length=121)
