# %%
import pandas as pd

mer_census = pd.read_csv('merged_census_data.csv')
mer_census
# Out:
#                                      Label (Grouping)  \
# 0                          Population 1 year and over
# 1                                                 AGE
# 2                                        1 to 4 years
# 3                                       5 to 17 years
# 4                                      18 to 24 years
# ..                                                ...
# 61        Population 1 year and over in housing units
# 62          Householder lived in owner-occupied ho...
# 63          Householder lived in renter-occupied h...
# 64                                  PERCENT ALLOCATED
# 65                               Residence 1 year ago
#
#    Florida!!Total!!Estimate Florida!!Total!!Margin of Error  \
# 0                21,590,684                          ±8,058
# 1                       NaN                             NaN
# 2                   901,510                          ±8,772
# 3                 3,195,869                          ±4,131
# ...

# %%
#Renaming the columns
mer_census_renamed = mer_census.rename(columns = {'Label (Grouping)':'Category',
                                          'Florida!!Total!!Estimate.10': '2010 TTL Estimate','Florida!!Moved; within same county!!Estimate.10':'2010 MF same county','Florida!!Moved; from different county, same state!!Estimate.10':'2010 MF diff county','Florida!!Moved; from different  state!!Estimate.10':'2010 MF diff state','Florida!!Moved; from abroad!!Estimate.10':'2010 MF abroad',
                                          'Florida!!Total!!Estimate.9': '2011 TTL Estimate','Florida!!Moved; within same county!!Estimate.9':'2011 MF same county','Florida!!Moved; from different county, same state!!Estimate.9':'2011 MF diff county','Florida!!Moved; from different  state!!Estimate.9':'2011 MF diff state','Florida!!Moved; from abroad!!Estimate.9':'2011 MF abroad', 
                                          'Florida!!Total!!Estimate.8': '2012 TTL Estimate','Florida!!Moved; within same county!!Estimate.8':'2012 MF same county','Florida!!Moved; from different county, same state!!Estimate.8':'2012 MF diff county','Florida!!Moved; from different  state!!Estimate.8':'2012 MF diff state','Florida!!Moved; from abroad!!Estimate.8':'2012 MF abroad', 
                                          'Florida!!Total!!Estimate.7': '2013 TTL Estimate','Florida!!Moved; within same county!!Estimate.7':'2013 MF same county','Florida!!Moved; from different county, same state!!Estimate.7':'2013 MF diff county','Florida!!Moved; from different  state!!Estimate.7':'2013 MF diff state','Florida!!Moved; from abroad!!Estimate.7':'2013 MF abroad', 
                                          'Florida!!Total!!Estimate.6': '2014 TTL Estimate','Florida!!Moved; within same county!!Estimate.6':'2014 MF same county','Florida!!Moved; from different county, same state!!Estimate.6':'2014 MF diff county','Florida!!Moved; from different  state!!Estimate.6':'2014 MF diff state','Florida!!Moved; from abroad!!Estimate.6':'2014 MF abroad',
                                          'Florida!!Total!!Estimate.5': '2015 TTL Estimate','Florida!!Moved; within same county!!Estimate.5':'2015 MF same county','Florida!!Moved; from different county, same state!!Estimate.5':'2015 MF diff county','Florida!!Moved; from different  state!!Estimate.5':'2015 MF diff state','Florida!!Moved; from abroad!!Estimate.5':'2015 MF abroad', 
                                          'Florida!!Total!!Estimate.4': '2016 TTL Estimate','Florida!!Moved; within same county!!Estimate.4':'2016 MF same county','Florida!!Moved; from different county, same state!!Estimate.4':'2016 MF diff county','Florida!!Moved; from different  state!!Estimate.4':'2016 MF diff state','Florida!!Moved; from abroad!!Estimate.4':'2016 MF abroad', 
                                          'Florida!!Total!!Estimate.3': '2017 TTL Estimate','Florida!!Moved; within same county!!Estimate.3':'2017 MF same county','Florida!!Moved; from different county, same state!!Estimate.3':'2017 MF diff county','Florida!!Moved; from different  state!!Estimate.3':'2017 MF diff state','Florida!!Moved; from abroad!!Estimate.3':'2017 MF abroad', 
                                          'Florida!!Total!!Estimate.2': '2018 TTL Estimate','Florida!!Moved; within same county!!Estimate.2':'2018 MF same county','Florida!!Moved; from different county, same state!!Estimate.2':'2018 MF diff county','Florida!!Moved; from different  state!!Estimate.2':'2018 MF diff state','Florida!!Moved; from abroad!!Estimate.2':'2018 MF abroad', 
                                          'Florida!!Total!!Estimate.1': '2019 TTL Estimate','Florida!!Moved; within same county!!Estimate.1':'2019 MF same county','Florida!!Moved; from different county, same state!!Estimate.1':'2019 MF diff county','Florida!!Moved; from different  state!!Estimate.1':'2019 MF diff state','Florida!!Moved; from abroad!!Estimate.1':'2019 MF abroad', 
                                          'Florida!!Total!!Estimate': '2021 TTL Estimate','Florida!!Moved; within same county!!Estimate':'2021 MF same county','Florida!!Moved; from different county, same state!!Estimate':'2021 MF diff county','Florida!!Moved; from different  state!!Estimate':'2021 MF diff state','Florida!!Moved; from abroad!!Estimate':'2021 MF abroad' 
                                          })



#Arraging the column in desired order
column_clean = mer_census_renamed[['Category',
                                   '2010 TTL Estimate','2011 TTL Estimate','2012 TTL Estimate','2013 TTL Estimate','2014 TTL Estimate','2015 TTL Estimate','2016 TTL Estimate','2017 TTL Estimate','2018 TTL Estimate','2019 TTL Estimate','2021 TTL Estimate',
                                   '2010 MF same county','2011 MF same county','2012 MF same county','2013 MF same county','2014 MF same county','2015 MF same county','2016 MF same county','2017 MF same county','2018 MF same county','2019 MF same county','2021 MF same county',
                                   '2010 MF diff county','2011 MF diff county','2012 MF diff county','2013 MF diff county','2014 MF diff county','2015 MF diff county','2016 MF diff county','2017 MF diff county','2018 MF diff county','2019 MF diff county','2021 MF diff county',
                                   '2010 MF diff state','2011 MF diff state','2012 MF diff state','2013 MF diff state','2014 MF diff state','2015 MF diff state','2016 MF diff state','2017 MF diff state','2018 MF diff state','2019 MF diff state','2021 MF diff state',
                                   '2010 MF abroad','2011 MF abroad','2012 MF abroad','2013 MF abroad','2014 MF abroad','2015 MF abroad','2016 MF abroad','2017 MF abroad','2018 MF abroad','2019 MF abroad','2021 MF abroad'
                                  ]]

#column_clean


#Selecting the needed rows
clean_data = column_clean.iloc[[0,11,54,62,63]]
clean_data
# Out:
#                                              Category 2010 TTL Estimate  \
# 0                          Population 1 year and over        18,647,600
# 11                                 Median age (years)              41.1
# 54                            Median income (dollars)            22,729
# 62          Householder lived in owner-occupied ho...        12,421,033
# 63          Householder lived in renter-occupied h...         5,804,858
#
#    2011 TTL Estimate 2012 TTL Estimate 2013 TTL Estimate 2014 TTL Estimate  \
# 0         18,863,948        19,114,620        19,345,059        19,683,763
# 11              41.4              41.6              41.9              42.1
# 54            23,173            23,387            23,749            24,405
# 62        12,291,643        12,218,453        12,166,097        12,234,061
# 63         6,150,713         6,471,037         6,753,082         7,018,239
#
#    2015 TTL Estimate 2016 TTL Estimate 2017 TTL Estimate 2018 TTL Estimate  \
# ...

# %%
fl_population = clean_data.iloc[:, 0:12]
fl_population.set_index('Category', inplace=True)
fl_population
# Out:
#                                                    2010 TTL Estimate  \
# Category
# Population 1 year and over                                18,647,600
#         Median age (years)                                      41.1
#         Median income (dollars)                               22,729
#         Householder lived in owner-occupied hou...        12,421,033
#         Householder lived in renter-occupied ho...         5,804,858
#
#                                                    2011 TTL Estimate  \
# Category
# Population 1 year and over                                18,863,948
#         Median age (years)                                      41.4
#         Median income (dollars)                               23,173
#         Householder lived in owner-occupied hou...        12,291,643
#         Householder lived in renter-occupied ho...         6,150,713
#
#                                                    2012 TTL Estimate  \
# Category
# ...

# %%
migration_from_different_state = clean_data.iloc[:, [0] + list(range(34, 45))]
migration_from_different_state.set_index('Category', inplace=True)
migration_from_different_state
# Out:
#                                                    2010 MF diff state  \
# Category
# Population 1 year and over                                      2.60%
#         Median age (years)                                       35.1
#         Median income (dollars)                                20,464
#         Householder lived in owner-occupied hou...              1.50%
#         Householder lived in renter-occupied ho...              4.50%
#
#                                                    2011 MF diff state  \
# Category
# Population 1 year and over                                      2.60%
#         Median age (years)                                       34.4
#         Median income (dollars)                                21,568
#         Householder lived in owner-occupied hou...              1.50%
#         Householder lived in renter-occupied ho...              4.50%
#
#                                                    2012 MF diff state  \
# Category
# ...

# %%
migration_from_abroad = clean_data.iloc[:, [0] + list(range(45, 56))]
migration_from_abroad.set_index('Category', inplace=True)
migration_from_abroad
# Out:
#                                                    2010 MF abroad  \
# Category
# Population 1 year and over                                  0.80%
#         Median age (years)                                   33.2
#         Median income (dollars)                            15,037
#         Householder lived in owner-occupied hou...          0.50%
#         Householder lived in renter-occupied ho...          1.40%
#
#                                                    2011 MF abroad  \
# Category
# Population 1 year and over                                  0.90%
#         Median age (years)                                   33.4
#         Median income (dollars)                            16,340
#         Householder lived in owner-occupied hou...          0.60%
#         Householder lived in renter-occupied ho...          1.50%
#
#                                                    2012 MF abroad  \
# Category
# Population 1 year and over                                  0.90%
# ...

# %%
# Flip the columns and rows of the DataFrame
flipped = migration_from_different_state.transpose()

# Print the flipped DataFrame
print(flipped)
# Out:
# Category           Population 1 year and over         Median age (years)  \
# 2010 MF diff state                      2.60%                       35.1
# 2011 MF diff state                      2.60%                       34.4
# 2012 MF diff state                      2.80%                       35.1
# 2013 MF diff state                      2.70%                       35.2
# 2014 MF diff state                      2.80%                       36.2
# 2015 MF diff state                      2.90%                       37.5
# 2016 MF diff state                      3.00%                       37.2
# 2017 MF diff state                      2.70%                       37.9
# 2018 MF diff state                      2.80%                       37.3
# 2019 MF diff state                      2.80%                       37.5
# 2021 MF diff state                      3.10%                       36.7
#
# Category                   Median income (dollars)  \
# ...
